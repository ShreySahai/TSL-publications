# %%
# Add lab members

# %%
import json
from scholarly import scholarly

def load_lab_members(filename="lab_members.json"):
    """
    Load the existing lab members from the JSON file.
    If the file doesn't exist, create it and return an empty list.
    """
    try:
        with open(filename, 'r') as json_file:
            return json.load(json_file)
    except FileNotFoundError:
        print(f"{filename} not found. Creating a new file.")
        # If the file doesn't exist, return an empty list
        with open(filename, 'w') as json_file:
            json.dump([], json_file, indent=4)  # Create an empty list and save to the file
        return []
    except json.JSONDecodeError:
        print(f"Error reading {filename}. The file may be corrupted.")
        return []

def save_lab_members(lab_members, filename="lab_members.json"):
    """
    Save the list of lab members to the JSON file.
    """
    try:
        with open(filename, 'w') as json_file:
            json.dump(lab_members, json_file, indent=4)
        print(f"Lab members saved to {filename}")
    except Exception as e:
        print(f"Error saving lab members: {e}")

def add_lab_member(scholar_id=None, search_query=None, filename="lab_members.json"):
    """
    Add a lab member to the lab_members.json file.
    You can pass either a Google Scholar ID or a search query (name) to find the member.
    """
    if scholar_id:
        # Use the provided Scholar ID to fetch the member
        print(f"Fetching details for author ID {scholar_id}...")
        author = scholarly.fill(scholarly.search_author_id(scholar_id))
    elif search_query:
        # Use the provided search query to find the member
        print(f"Searching for {search_query}...")
        search_query_result = scholarly.search_author(search_query)
        try:
            author = next(search_query_result)  # Get the first result
            author = scholarly.fill(author)
        except StopIteration:
            print(f"No results found for {search_query}.")
            return
    else:
        print("Error: Either scholar_id or search_query must be provided.")
        return
    
    # Get the author's details (e.g., name, publications)
    author_data = {
        'name': author['name'],
        'scholar_id': author['scholar_id'],
        'affiliation': author.get('affiliation', 'N/A'),
        'interests': author.get('interests', 'N/A'),
        'publications_count': len(author['publications'])
    }
    
    # Load existing lab members
    lab_members = load_lab_members(filename)
    
    # Check if the member already exists in the list (using the scholar_id)
    if any(member['scholar_id'] == author_data['scholar_id'] for member in lab_members):
        print(f"{author_data['name']} is already in the lab members list.")
    else:
        # Add the new lab member to the list
        lab_members.append(author_data)
        save_lab_members(lab_members, filename)
        print(f"{author_data['name']} has been added to the lab members list.")

# %%
# Add professor.

# %%
add_lab_member(scholar_id='wGXkEP0AAAAJ')  # Replace with a real name
# Out:
# Fetching details for author ID wGXkEP0AAAAJ...
# lab_members.json not found. Creating a new file.
# Lab members saved to lab_members.json
# Pramod Kumar has been added to the lab members list.

# %%
# Expand the lab

# %%
def get_coauthors(author_id):
    """
    Retrieve the co-authors of a given author using their Google Scholar ID.
    """
    try:
        # Fetch the author's publications
        return scholarly.fill(scholarly.search_author_id(author_id),sections=['coauthors'])['coauthors']  
    except Exception as e:
        print(f"Error retrieving co-authors for author ID {author_id}: {e}")
        return []


def add_coauthors_of_lab_members(filename="lab_members.json"):
    """
    Extract co-authors from existing lab members and add them if they're not already in the lab.
    """
    lab_members = load_lab_members(filename)
    
    # Iterate over each lab member and get their co-authors
    for member in lab_members:
        print(f"Processing co-authors for {member['name']}...")
        coauthors = get_coauthors(member['scholar_id'])
        
        for coauthor in coauthors:
            # Check if the coauthor is already in the lab
            existing_member = next((m for m in lab_members if m['name'] == coauthor), None)
            if existing_member:
                print(f"{coauthor['name']} is already in the lab.")
            else:
                print(f"Do you want to add {coauthor['name']} to the lab? (y/n)")
                answer = input().strip().lower()
                if answer == 'y':
                    add_lab_member(scholar_id = coauthor['scholar_id'])

# %%
add_coauthors_of_lab_members(filename="lab_members.json")
# Out:
# Processing co-authors for Pramod Kumar...
# Do you want to add Pradip Dutta to the lab? (y/n)
# n
# Do you want to add Kandadai Srinivasan to the lab? (y/n)
# n
# Do you want to add Pardeep Garg to the lab? (y/n)
# y
# Fetching details for author ID 9PyletoAAAAJ...
# Lab members saved to lab_members.json
# Pardeep Garg has been added to the lab members list.
# Do you want to add Yogendra Joshi to the lab? (y/n)
# n
# Do you want to add Sourav Mitra to the lab? (y/n)
# n
# Do you want to add SS MURTHY to the lab? (y/n)
# n
# Do you want to add Lakshminarayanan Seshadri to the lab? (y/n)
# y
# Fetching details for author ID 9xPo_qsAAAAJ...
# Lab members saved to lab_members.json
# Lakshminarayanan Seshadri has been added to the lab members list.
# Do you want to add Srisha MV Rao to the lab? (y/n)
# n
# Do you want to add Clifford Ho to the lab? (y/n)
# n
# Do you want to add Pradeep Gupta to the lab? (y/n)
# y
# Fetching details for author ID iRe_oUMAAAAJ...
# Lab members saved to lab_members.json
# Pradeep Gupta has been added to the lab members list.
# Do you want to add Syed J Hoque to the lab? (y/n)
# y
# Fetching details for author ID Z4tDyMEAAAAJ...
# Lab members saved to lab_members.json
# Syed J Hoque has been added to the lab members list.
# Do you want to add ASHUTOSH PATEL to the lab? (y/n)
# y
# Fetching details for author ID LXh0SNcAAAAJ...
# Lab members saved to lab_members.json
# ASHUTOSH PATEL has been added to the lab members list.
# Do you want to add G Narayanan to the lab? (y/n)
# n
# Do you want to add Vivek Pandey to the lab? (y/n)
# y
# Fetching details for author ID BknpyzIAAAAJ...
# Lab members saved to lab_members.json
# Vivek Pandey has been added to the lab members list.
# Do you want to add Matthew Orosz to the lab? (y/n)
# n
# Do you want to add Suman Chakraborty to the lab? (y/n)
# n
# Do you want to add Syed Shahjahan Ahmad to the lab? (y/n)
# n
# Do you want to add Abdul Nassar to the lab? (y/n)
# n
# Do you want to add Dr. Sharath Sathish to the lab? (y/n)
# y
# Fetching details for author ID dcyu5ucAAAAJ...
# Lab members saved to lab_members.json
# Dr. Sharath Sathish has been added to the lab members list.
# Do you want to add Katamala Malleswararao to the lab? (y/n)
# n
# Do you want to add Shreyas Srivatsa, PhD to the lab? (y/n)
# n
# Do you want to add Prof. Nilkanta Barman to the lab? (y/n)
# n
# Do you want to add Vaibhav Arghode to the lab? (y/n)
# n
# Do you want to add Ada Gavrilovska to the lab? (y/n)
# n
# Do you want to add Kundan Kumar to the lab? (y/n)
# y
# Fetching details for author ID YokW28IAAAAJ...
# Lab members saved to lab_members.json
# Kundan Kumar has been added to the lab members list.
# Do you want to add Sanjoy Paul to the lab? (y/n)
# y
# Fetching details for author ID OfRkFNcAAAAJ...
# Lab members saved to lab_members.json
# Sanjoy Paul has been added to the lab members list.
# Do you want to add Kamisetti NV Prasad to the lab? (y/n)
# n

# %%
for scholar_id in ['p0Nb_g0AAAAJ','V3rWzEsAAAAJ']:
    add_lab_member(scholar_id=scholar_id)
# Out:
# Fetching details for author ID p0Nb_g0AAAAJ...
# Lab members saved to lab_members.json
# Shrey Sahai Gupta has been added to the lab members list.
# Fetching details for author ID V3rWzEsAAAAJ...
# Lab members saved to lab_members.json
# SHUBHAM KUMAR VISHWAKARMA has been added to the lab members list.

# %%
shrey = scholarly.fill(scholarly.search_author_id('p0Nb_g0AAAAJ'))

# %%
shrey['publications'][0]
# Out:
# {'container_type': 'Publication',
#  'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#  'bib': {'title': 'Optimal Part-Load Control of Supercritical Carbon Dioxide Brayton Cycles',
#   'pub_year': '2024',
#   'citation': 'Journal of Engineering for Gas Turbines and Power, 1-42, 2024'},
#  'filled': False,
#  'author_pub_id': 'p0Nb_g0AAAAJ:W7OEmFMy1HYC',
#  'num_citations': 0}

# %%
import json

def load_publications(filename="publications.json"):
    """
    Load the existing publications from the JSON file.
    If the file doesn't exist, create it and return an empty list.
    """
    try:
        with open(filename, 'r') as json_file:
            return json.load(json_file)
    except FileNotFoundError:
        print(f"{filename} not found. Creating a new file.")
        with open(filename, 'w') as json_file:
            json.dump([], json_file, indent=4)
        return []
    except json.JSONDecodeError:
        print(f"Error reading {filename}. The file may be corrupted.")
        return []

def save_publications(publications, filename="publications.json"):
    """
    Save the list of publications to the JSON file.
    """
    try:
        with open(filename, 'w') as json_file:
            json.dump(publications, json_file, indent=4)
        print(f"Publications saved to {filename}")
    except Exception as e:
        print(f"Error saving publications: {e}")

def add_publication(search_query, filename="publications.json"):
    """
    Add a new publication to the publications.json file.
    The publication should be a dictionary containing relevant details.
    """
    # Load existing publications
    publications = load_publications(filename)
    # Details of new publication
    publication_details = scholarly.fill(next(scholarly.search_pubs(search_query)))
    
    # Check if the publication already exists in the list
    if any(pub['bib']['title'] == publication_details['bib']['title'] and pub['bib']['pub_year'] == publication_details['bib']['pub_year'] for pub in publications):
        print(f"The publication '{publication_details['bib']['title']}' from {publication_details['bib']['pub_year']} already exists in the list.")
    else:
        # Add the new publication
        
        publications.append(publication_details)
        # Save the updated publications list to the file
        save_publications(publications, filename)
        print(f"Publication '{publication_details['bib']['title']}' added to the list.")

# %%
def retrieve_publication_titles_for_lab_members(lab_members_filename="lab_members.json"):
    """
    Retrieve publication titles for all lab members and print them.
    """
    # Load lab members
    lab_members = load_lab_members(lab_members_filename)
    
    all_publication_titles = {}

    # Iterate over each lab member to retrieve their publication titles
    for member in lab_members:
        scholar_id = member.get('scholar_id')
        if scholar_id:
            print(f"Retrieving publications for {member['name']} (ID: {scholar_id})")
            
            # Search for the author by scholar_id
            search_query = scholarly.search_author_id(scholar_id)
            try:
                author = next(search_query)
                publications = scholarly.fill(author)['publications']
                
                # Collect the titles of publications
                publication_titles = [pub['bib']['title'] for pub in publications]
                
                all_publication_titles[member['name']] = publication_titles
                
            except StopIteration:
                print(f"Author with ID '{scholar_id}' not found.")
        else:
            print(f"Missing scholar_id for lab member '{member['name']}'.")

    # Return the dictionary of lab members and their publication titles
    return all_publication_titles

# Example usage
publication_titles = retrieve_publication_titles_for_lab_members()

# Print the retrieved publication titles
for member, titles in publication_titles.items():
    print(f"\n{member}'s Publications:")
    for title in titles:
        print(f" - {title}")
# Out:
# Retrieving publications for Pramod Kumar (ID: wGXkEP0AAAAJ)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32012\4187394896.py in <module>
#      34
#      35 # Example usage
# ---> 36 publication_titles = retrieve_publication_titles_for_lab_members()
#      37
#      38 # Print the retrieved publication titles
#
# ~\AppData\Local\Temp\ipykernel_32012\4187394896.py in retrieve_publication_titles_for_lab_members(lab_members_filename)
#      17             search_query = scholarly.search_author_id(scholar_id)
#      18             try:
# ---> 19                 author = next(search_query)
#      20                 publications = scholarly.fill(author)['publications']
#      21
#
# TypeError: 'dict' object is not an iterator

# %%
search_query = 'Optimal Part-Load Performance of Supercritical Carbon Dioxide Brayton Cycles During Inventory Control'
add_publication(search_query, filename="publications.json")
# Out:
# Publications saved to publications.json
# Publication 'Optimal Part-Load Performance of Supercritical Carbon Dioxide Brayton Cycles During Inventory Control' added to the list.

# %%
scholarly.fill(next(scholarly.search_pubs("Maximum Power Operation Of A Supercritical Carbon Dioxide Simple Recuperated Brayton Power Block")))
# Out:
# {'container_type': 'Publication',
#  'source': <PublicationSource.PUBLICATION_SEARCH_SNIPPET: 'PUBLICATION_SEARCH_SNIPPET'>,
#  'bib': {'title': 'Maximum Power Operation Of A Supercritical Carbon Dioxide Simple Recuperated Brayton Power Block',
#   'author': 'Gupta, Shrey Sahai and Kumar, Pramod',
#   'pub_year': '2024',
#   'venue': 'Proceedings of the 27th National and 5th …',
#   'abstract': 'Supercritical Carbon Dioxide (sCO 2) is gaining attention as a promising option for efficient and low-carbon-footprint power generation. These compact systems are particularly wellsuited for arid regions due to the feasibility of dry-cooled operation. This study investigates the design of sCO 2 Brayton cycles for peak-power generation applications, focusing on a 5 megawatt (MW) simple recuperated plant with fixed heat exchanger conductance. The maximum power capacity of the plant was analyzed by varying',
#   'organization': 'Begel House Inc.',
#   'booktitle': 'Proceedings of the 27th National and 5th International ISHMT-ASTFE Heat and Mass Transfer Conference December 14-17, 2023, IIT Patna, Patna-801106, Bihar, India',
#   'pub_type': 'inproceedings',
#   'bib_id': 'gupta2024maximum'},
#  'filled': True,
#  'gsrank': 1,
#  'pub_url': 'https://www.dl.begellhouse.com/references/1654896405e56590,4869f8107409fb40,3812ba592211ea47.html',
#  'author_id': ['p0Nb_g0AAAAJ', 'OLjqlAIAAAAJ'],
#  'url_scholarbib': '/scholar?hl=en&q=info:sMXp49fyGLsJ:scholar.google.com/&output=cite&scirp=0&hl=en',
#  'url_add_sclib': '/citations?hl=en&xsrf=&continue=/scholar%3Fq%3DMaximum%2BPower%2BOperation%2BOf%2BA%2BSupercritical%2BCarbon%2BDioxide%2BSimple%2BRecuperated%2BBrayton%2BPower%2BBlock%26hl%3Den%26as_sdt%3D0,33&citilm=1&update_op=library_add&info=sMXp49fyGLsJ&ei=dTRZZ8KcEqWs6rQPpKq1wQM&json=',
#  'num_citations': 0,
#  'url_related_articles': '/scholar?q=related:sMXp49fyGLsJ:scholar.google.com/&scioq=Maximum+Power+Operation+Of+A+Supercritical+Carbon+Dioxide+Simple+Recuperated+Brayton+Power+Block&hl=en&as_sdt=0,33',
#  'eprint_url': 'https://www.researchgate.net/profile/Shrey-Gupta-4/publication/379838569_Maximum_Power_Operation_Of_A_Supercritical_Carbon_Dioxide_Simple_Recuperated_Brayton_Power_Block/data/661e31b939e7641c0bcaf2bb/Manuscript-File-Paper-No-293.pdf'}

# %%
def update_publications_lab_members(lab_members_filename = "lab_members.json",filename="publications.json"):
    """
    Add a new publication to the publications.json file.
    The publication should be a dictionary containing relevant details.
    """
    # Load existing publications
    publications = load_publications(filename)
    # Details of new publication
    lab_members = load_lab_members(lab_members_filename)
    
    for member in lab_members:
        scholar_id = member.get('scholar_id')
        print(f"Retrieving publications for {member['name']} (ID: {scholar_id})")
        all_publications = scholarly.fill(scholarly.search_author_id(scholar_id))['publications']
    
        for publication in all_publications:
            title = publication['bib']['title']
            print(title,end="\n\n")
            add_publication(title)
#             # Check if the publication already exists in the list
#             try:
#                 if any(pub['bib']['title'] == publication['bib']['title'] and pub['bib']['pub_year'] == publication['bib']['pub_year'] for pub in publications):
#                     print(f"The publication '{publication['bib']['title']}' from {publication['bib']['pub_year']} already exists in the list.")
#                 else:
#                     # Add the new publication
#                     print(f"Do you want to add \"{title}\" to the lab publications? (y/n)")
#                     answer = input().strip().lower()
#                     if answer == 'y':
#                         publications.append(publication)
#                         print(f"Publication '{publication['bib']['title']}' added to the list.")
#             except:
#                 print(f"The publication '{publication['bib']['title']}' could not be added.")
    # Save the updated publications list to the file
    save_publications(publications, filename)

# %%
update_publications_lab_members()
# Out:
# Retrieving publications for Pramod Kumar (ID: wGXkEP0AAAAJ)
# Supercritical carbon dioxide Brayton cycle for concentrated solar power

# %%
def retrieve_publication_titles_for_lab_members(lab_members_filename="lab_members.json"):
    """
    Retrieve publication titles for all lab members and print them.
    """
    # Load lab members
    lab_members = load_lab_members(lab_members_filename)
    
    all_publication_titles = []

    # Iterate over each lab member to retrieve their publication titles
    for member in lab_members:
        scholar_id = member.get('scholar_id')
        print(f"Retrieving publications for {member['name']} (ID: {scholar_id})")
        all_publications = scholarly.fill(scholarly.search_author_id(scholar_id))['publications']
        
        for pub in all_publications:
            title = pub['bib']['title']
            existing_publication = next((p for p in all_publication_titles if p == title), None)
            if existing_publication:
                pass 
            else:
                print(f"Do you want to add "{title}" to the lab publications? (y/n)")
                answer = input().strip().lower()
                if answer == 'y':
                    all_publication_titles.append(title)
    return all_publication_titles

# Example usage
publication_titles = retrieve_publication_titles_for_lab_members()
# Out:
# Retrieving publications for Pramod Kumar (ID: wGXkEP0AAAAJ)
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Supercritical carbon dioxide Brayton cycle for concentrated solar power', 'pub_year': '2013', 'citation': 'The Journal of Supercritical Fluids 76, 54-60, 2013'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:ns9cj8rnVeAC', 'num_citations': 254, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10356142681150366177', 'cites_id': ['10356142681150366177']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Energy efficient thermal management of data centers', 'pub_year': '2012', 'citation': 'Springer Science & Business Media, 2012'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:dfsIfKJdRG4C', 'num_citations': 210, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12842796240832291266', 'cites_id': ['12842796240832291266']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Evaluation of isopentane, R-245fa and their mixtures as working fluids for organic Rankine cycles', 'pub_year': '2013', 'citation': 'Applied Thermal Engineering 51 (1-2), 292-300, 2013'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:aqlVkmm33-oC', 'num_citations': 163, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4610985673108081078', 'cites_id': ['4610985673108081078']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Technoeconomic Analysis of Alternative Solarized s-CO2 Brayton Cycle Configurations', 'pub_year': '2016', 'citation': 'Journal of Solar Energy Engineering 138 (5), 051008, 2016'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:hqOjcs7Dif8C', 'num_citations': 101, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3392090034623091733', 'cites_id': ['3392090034623091733']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Solar driven adsorption desalination system', 'pub_year': '2014', 'citation': 'Energy Procedia 49, 2261-2269, 2014'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:Y0pCki6q_DkC', 'num_citations': 93, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1504394405164014740', 'cites_id': ['1504394405164014740']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Performance evaluation of a two-stage silica gel+ water adsorption based cooling-cum-desalination system', 'pub_year': '2015', 'citation': 'international journal of refrigeration 58, 186-198, 2015'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:SeFeTyx0c_EC', 'num_citations': 91, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11857226948032311170', 'cites_id': ['11857226948032311170']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Evaluation of carbon dioxide blends with isopentane and propane as working fluids for organic Rankine cycles', 'pub_year': '2013', 'citation': 'Applied Thermal Engineering 52 (2), 439-448, 2013'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:ZeXyd9-uunAC', 'num_citations': 84, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5533028497965064892', 'cites_id': ['5533028497965064892']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Studies on transport phenomena during solidification of an aluminum alloy in the presence of linear electromagnetic stirring', 'pub_year': '2009', 'citation': 'Journal of Materials Processing Technology 209 (18-19), 5912-5923, 2009'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:RHpTSmoSYBkC', 'num_citations': 66, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7178227866954113524', 'cites_id': ['7178227866954113524']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Thermo-economic evaluation of ORCs for various working fluids', 'pub_year': '2016', 'citation': 'Applied Thermal Engineering 109, 841-853, 2016'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:738O_yMBCRsC', 'num_citations': 65, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17220334039262568572', 'cites_id': ['17220334039262568572']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Comparison of CO2 and steam in transcritical Rankine cycles for concentrated solar power', 'pub_year': '2014', 'citation': 'Energy procedia 49, 1138-1146, 2014'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:TQgYirikUcIC', 'num_citations': 63, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6315589894326333590', 'cites_id': ['6315589894326333590']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Rack level modeling of air flow through perforated tile in a data center', 'pub_year': '2013', 'citation': 'Journal of Electronic Packaging 135 (3), 030902, 2013'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:NaGl4SEjCO4C', 'num_citations': 63, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10434822351747356654', 'cites_id': ['10434822351747356654']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Carbon dioxide based power generation in renewable energy systems', 'pub_year': '2016', 'citation': 'Applied Thermal Engineering 109, 831-840, 2016'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:_xSYboBqXhAC', 'num_citations': 60, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13832095207630848254', 'cites_id': ['13832095207630848254']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Development and performance studies of an air cooled two-stage multi-bed silica-gel+ water adsorption system', 'pub_year': '2016', 'citation': 'international journal of refrigeration 67, 174-189, 2016'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:IWHjjKOFINEC', 'num_citations': 56, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5737689694662516340', 'cites_id': ['5737689694662516340']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Cost and Performance Tradeoffs of Alternative Solar-Driven S-CO2 Brayton Cycle Configurations', 'pub_year': '2015', 'citation': 'Energy sustainability 56840, V001T05A016, 2015'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:4JMBOYKVnBMC', 'num_citations': 50, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7238260416719711437', 'cites_id': ['7238260416719711437']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Simulation study of a two-stage adsorber system', 'pub_year': '2014', 'citation': 'Applied thermal engineering 72 (2), 283-288, 2014'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:zA6iFVUQeVQC', 'num_citations': 47, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12678168089163279366', 'cites_id': ['12678168089163279366']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Development of a generic tool to design scroll expanders for ORC applications', 'pub_year': '2016', 'citation': 'Applied Thermal Engineering 109, 878-888, 2016'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:p2g8aNsByqUC', 'num_citations': 43, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16404446365511076085', 'cites_id': ['16404446365511076085']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Experimental investigations on the effect of perforated tile air jet velocity on server air distribution in a high density data center', 'pub_year': '2010', 'citation': '2010 12th IEEE Intersociety Conference on Thermal and Thermomechanical …, 2010'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:IjCSPb-OGe4C', 'num_citations': 43, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1065859041571324778', 'cites_id': ['1065859041571324778']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Spatially-aware optimization of energy consumption in consolidated data center systems', 'pub_year': '2011', 'citation': 'International Electronic Packaging Technical Conference and Exhibition 44625 …, 2011'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:KlAtU1dfN6UC', 'num_citations': 40, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3971584672735702912', 'cites_id': ['3971584672735702912']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Experiments on a novel metal hydride cartridge for hydrogen storage and low temperature thermal storage', 'pub_year': '2022', 'citation': 'International Journal of Hydrogen Energy 47 (36), 16144-16155, 2022'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:8LfMcXwVQboC', 'num_citations': 39, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9221555237606993943', 'cites_id': ['9221555237606993943']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Thermo-hydraulic analysis of compact heat exchanger for a simple recuperated sCO2 Brayton cycle', 'pub_year': '2020', 'citation': 'Renewable and Sustainable Energy Reviews 134, 110091, 2020'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:_axFR9aDTf0C', 'num_citations': 38, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=583196694570017714', 'cites_id': ['583196694570017714']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Studies on turbulent momentum, heat and species transport during binary alloy solidification in a top-cooled rectangular cavity', 'pub_year': '2003', 'citation': 'International journal of heat and mass transfer 46 (7), 1115-1137, 2003'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:LkGwnXOMwfcC', 'num_citations': 34, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3009332863534967185', 'cites_id': ['3009332863534967185']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Effect of server load variation on rack air flow distribution in a raised floor data center', 'pub_year': '2011', 'citation': '2011 27th Annual IEEE Semiconductor Thermal Measurement and Management …, 2011'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:blknAaTinKkC', 'num_citations': 32, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9011113983544468085', 'cites_id': ['9011113983544468085']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Solar driven carbon dioxide Brayton cycle power generation with thermal compression', 'pub_year': '2016', 'citation': 'Applied Thermal Engineering 109, 854-860, 2016'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:SP6oXDckpogC', 'num_citations': 31, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15925663098457593341', 'cites_id': ['15925663098457593341']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Experimental investigations on mixing characteristics in the critical regime of a low-area ratio supersonic ejector', 'pub_year': '2019', 'citation': 'Physics of Fluids 31 (2), 2019'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:-jrNzM816MMC', 'num_citations': 30, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6447834390218392066', 'cites_id': ['6447834390218392066']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Analysis of a hybrid transcritical CO2 vapor compression and vapor ejector refrigeration system', 'pub_year': '2020', 'citation': 'Applied Thermal Engineering 181, 115945, 2020'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:BrmTIyaxlBUC', 'num_citations': 28, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=14452470301901856610', 'cites_id': ['14452470301901856610']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Rayleigh-Benard convection during solidification of an eutectic solution cooled from the top', 'pub_year': '2002', 'citation': 'Metallurgical and Materials Transactions B 33, 605-612, 2002'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:KxtntwgDAa4C', 'num_citations': 28, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15725903558746868888', 'cites_id': ['15725903558746868888']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Dynamics of cold aisle air distribution in a raised floor data center', 'pub_year': '2010', 'citation': '2010 3rd International Conference on Thermal Issues in Emerging Technologies …, 2010'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:u9iWguZQMMsC', 'num_citations': 25, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16658351848310432115', 'cites_id': ['16658351848310432115']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Cold aisle air distribution in a raised floor data center with heterogeneous opposing orientation racks', 'pub_year': '2011', 'citation': 'International Electronic Packaging Technical Conference and Exhibition 44625 …, 2011'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:iH-uZ7U-co4C', 'num_citations': 24, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7305854884283288621', 'cites_id': ['7305854884283288621']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Artificial neural network model for single-phase real gas ejectors', 'pub_year': '2022', 'citation': 'Applied thermal engineering 201, 117615, 2022'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:vofGIMt6cyEC', 'num_citations': 23, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10479712370922862877', 'cites_id': ['10479712370922862877']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Introduction to data center energy flow and thermal management', 'pub_year': '2012', 'citation': 'Energy Efficient Thermal Management of Data Centers, 1-38, 2012'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:YOwf2qJgpHMC', 'num_citations': 23, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4181412525191104098', 'cites_id': ['4181412525191104098']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Fundamentals of data center airflow management', 'pub_year': '2012', 'citation': 'Energy efficient thermal management of data centers, 39-136, 2012'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:f2IySw72cVMC', 'num_citations': 21, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13692435155284888403', 'cites_id': ['13692435155284888403']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Artificial neural network based shape optimization of supersonic ejectors in the critical flow regime', 'pub_year': '2022', 'citation': 'Applied Thermal Engineering 216, 119046, 2022'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:TpYZtc-0n-8C', 'num_citations': 19, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13547663933614031300', 'cites_id': ['13547663933614031300']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'A trade-off between maxima in efficiency and specific work output of super-and trans-critical CO2 Brayton cycles', 'pub_year': '2015', 'citation': 'The Journal of Supercritical Fluids 98, 119-126, 2015'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:qjMakFHDy7sC', 'num_citations': 19, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=874596545652383141', 'cites_id': ['874596545652383141']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Phase field simulation of equiaxed microstructure formation during semi-solid processing of A380 Al alloy', 'pub_year': '2014', 'citation': 'ISIJ international 54 (7), 1601-1610, 2014'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:a0OBvERweLwC', 'num_citations': 19, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13419731423192017307', 'cites_id': ['13419731423192017307']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Organic Brayton Cycles with solid sorption thermal compression for low grade heat utilization', 'pub_year': '2014', 'citation': 'Applied thermal engineering 62 (1), 171-175, 2014'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:NMxIlDl6LWMC', 'num_citations': 17, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9246684326845655167', 'cites_id': ['9246684326845655167']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Induction reheating of A356. 2 aluminum alloy and thixocasting as automobile component', 'pub_year': '2010', 'citation': 'Transactions of Nonferrous Metals Society of China 20, s961-s967, 2010'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:2osOgNQ5qMEC', 'num_citations': 17, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=835099175783279472', 'cites_id': ['835099175783279472']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Analysis of a Dual Recuperated Dual Expansion Supercritical CO2 Cycle for Waste Heat Recovery Applications', 'pub_year': '2021', 'citation': 'Transactions of the Indian National Academy of Engineering 6, 439-459, 2021'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:CdxZDUztZiMC', 'num_citations': 16, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9273635538869409998', 'cites_id': ['9273635538869409998']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Electromagnetic design of a 5-kW, 10,000-rpm switched reluctance machine', 'pub_year': '2016', 'citation': '2016 7th India International Conference on Power Electronics (IICPE), 1-6, 2016'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:L8Ckcad2t8MC', 'num_citations': 15, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5521118143760449727', 'cites_id': ['5521118143760449727']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Silica gel+ water adsorber chiller and desalination system: a transient heat transfer study', 'pub_year': '2016', 'citation': 'Journal of Thermal Science and Engineering Applications 8 (2), 021014, 2016'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:rO6llkc54NcC', 'num_citations': 13, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12448468204675519068', 'cites_id': ['12448468204675519068']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Instrumentation and control of a two-stage 4-bed silica gel+ water adsorption cooling cum desalination system', 'pub_year': '2016', 'citation': 'Measurement 79, 29-43, 2016'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:M3NEmzRMIkIC', 'num_citations': 13, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8400220299000946998', 'cites_id': ['8400220299000946998']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Server heat load based CRAC fan controller paired with rear door heat exchanger', 'pub_year': '2011', 'citation': 'International Electronic Packaging Technical Conference and Exhibition 44625 …, 2011'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:Wp0gIr-vW9MC', 'num_citations': 13, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4982532774038699615', 'cites_id': ['4982532774038699615']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Analysis of Turbomachinery Losses in sCO2 Brayton Power Blocks', 'pub_year': '2022', 'citation': 'Journal of Energy Resources Technology 144 (11), 112101, 2022'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:fXbrI0tPCuEC', 'num_citations': 12, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=482591168891355027', 'cites_id': ['482591168891355027']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Novel Approaches for sCO2 Axial Turbine Design', 'pub_year': '2019', 'citation': 'Turbo Expo: Power for Land, Sea, and Air 58721, V009T38A011, 2019'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:fPk4N6BV_jEC', 'num_citations': 11, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12758375393937637965', 'cites_id': ['12758375393937637965']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Design of 20 kW turbomachinery for closed loop supercritical carbon dioxide Brayton test loop facility', 'pub_year': '2019', 'citation': 'Turbo Expo: Power for Land, Sea, and Air 58721, V009T38A016, 2019'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:JV2RwH3_ST0C', 'num_citations': 11, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8893177805644202701', 'cites_id': ['8893177805644202701']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Modeling thermal mass of a data center validated with actual data due to chiller failure', 'pub_year': '2011', 'citation': 'ASME International Mechanical Engineering Congress and Exposition 54969, 169-175, 2011'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:O3NaXMp0MMsC', 'num_citations': 11, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10162900248951012903', 'cites_id': ['10162900248951012903']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Experimental investigation of Rheocasting usinglinear electromagnetic stirring [D]', 'pub_year': '2008', 'citation': 'Indian Institute of Science, Bangalore, India, 2008'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:LTdYzzxxQecC', 'num_citations': 11, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10928516890340906329', 'cites_id': ['10928516890340906329']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Advanced low pressure cycle for concentrated solar power generation', 'pub_year': '2014', 'citation': 'Energy Sustainability 45868, V001T02A033, 2014'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:ldfaerwXgEUC', 'num_citations': 10, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11087078055588842680', 'cites_id': ['11087078055588842680']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Experimental studies and phase field modeling of microstructure evolution during solidification with electromagnetic stirring', 'pub_year': '2010', 'citation': 'Transactions of Nonferrous Metals Society of China 20, s774-s780, 2010'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:WbkHhVStYXYC', 'num_citations': 10, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17181949459028353997', 'cites_id': ['17181949459028353997']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Visualization of convection loops due to Rayleigh–Benard convection during solidification', 'pub_year': '2006', 'citation': 'Mechanics Research Communications 33 (5), 593-600, 2006'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:u_35RYKgDlwC', 'num_citations': 10, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12726823156809922718', 'cites_id': ['12726823156809922718']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Effect of supply air temperature on rack cooling in a high density raised floor data center facility', 'pub_year': '2011', 'citation': 'ASME International Mechanical Engineering Congress and Exposition 54921 …, 2011'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:RGFaLdJalmkC', 'num_citations': 9, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10425280284137556872', 'cites_id': ['10425280284137556872']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Experimental studies on LaNi4. 25Al0. 75 alloy for hydrogen and thermal energy storage applications', 'pub_year': '2023', 'citation': 'International Journal of Hydrogen Energy 48 (69), 26911-26920, 2023'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:PBZ9sWDp-nEC', 'num_citations': 8, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15477674106388243175', 'cites_id': ['15477674106388243175']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Supercritical carbon dioxide turbomachinery options for kilowatt to gigawatt level power generation', 'pub_year': '2019', 'citation': 'Gas Turbine India Conference 83532, V002T08A007, 2019'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:ZHo1McVdvXMC', 'num_citations': 8, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12036567172327893245', 'cites_id': ['12036567172327893245']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Design of an Experimental Test Facility for Supercritical CO2 Brayton Cycle', 'pub_year': '2014', 'citation': 'Energy Sustainability 45868, V001T05A005, 2014'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:EUQCXRtRnyEC', 'num_citations': 8, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=14276455386105238439', 'cites_id': ['14276455386105238439']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'CONCENTRATING SOLAR POWERED TRANSCRITICAL CO2 POWER GENERATION CYCLE FOR THE UNION TERRITORY OF LADAKH, INDIA', 'pub_year': '2023', 'citation': 'International Journal of Energy for a Clean Environment 24 (4), 2023'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:Qovp55VTycgC', 'num_citations': 7, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4952844673077453966', 'cites_id': ['4952844673077453966']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Harmonic analysis of the high speed direct coupled SCO2 turbo-generator', 'pub_year': '2021', 'citation': 'Gas Turbine India Conference 85536, V001T10A010, 2021'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:esGtpfCv0y8C', 'num_citations': 7, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3854425847936777087', 'cites_id': ['3854425847936777087']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Simple recuperated S-CO2 cycle revisited: Optimization of operating parameters for maximum cycle efficiency', 'pub_year': '2019', 'citation': 'Turbo Expo: Power for Land, Sea, and Air 58721, V009T38A002, 2019'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:uWQEDVKXjbEC', 'num_citations': 7, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16076966250126982478', 'cites_id': ['16076966250126982478']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Experimental characterization of transient temperature evolution in a data center facility', 'pub_year': '2011', 'citation': 'Power 8, 18, 2011'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:3s1wT3WcHBgC', 'num_citations': 6, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12409355685697884263', 'cites_id': ['12409355685697884263']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Low-frequency unsteadiness of recompression shock structures in the diffuser of supersonic ejectors', 'pub_year': '2023', 'citation': 'Physics of Fluids 35 (3), 2023'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:L8oS6_awjPoC', 'num_citations': 5, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12092202606465397932', 'cites_id': ['12092202606465397932']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Thermodynamic analysis on the effect of supercritical CO2 ejector in cogeneration cycle for dairy application', 'pub_year': '2023', 'citation': 'Thermal Science and Engineering Progress 39, 101729, 2023'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:9Pw2l-cN0AIC', 'num_citations': 5, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2696397703695280258', 'cites_id': ['2696397703695280258']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Influence of Geometric Parameters for a 100\u2009kW Inward Flow Radial Supercritical CO2 Turbine', 'pub_year': '2023', 'citation': 'Journal of Engineering for Gas Turbines and Power 145 (1), 011020, 2023'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:KKhxhHPhcTsC', 'num_citations': 5, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4243782839927348418', 'cites_id': ['4243782839927348418']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Development of a canister module for PCM coupled heat pipe in spacecraft thermal management', 'pub_year': '2021', 'citation': 'IEEE Transactions on Components, Packaging and Manufacturing Technology 11 …, 2021'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:rqnDXT1GswoC', 'num_citations': 5, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16425906781546427328', 'cites_id': ['16425906781546427328']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Experimental vibration studies on a solid-rotor switched reluctance machine', 'pub_year': '2021', 'citation': 'IEEE Transactions on Industry Applications 57 (5), 4852-4863, 2021'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:1sJd4Hv_s6UC', 'num_citations': 5, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16078703387628010541', 'cites_id': ['16078703387628010541']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Effect of parasitic losses on the design optimization of inward flow radial supercritical CO2 turbines', 'pub_year': '2024', 'citation': 'Proceedings of the Institution of Mechanical Engineers, Part A: Journal of …, 2024'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:62yiFa7nMbkC', 'num_citations': 4, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6478090994826616712', 'cites_id': ['6478090994826616712']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Experimental investigations on a coupled metal hydride based thermal energy storage system', 'pub_year': '2024', 'citation': 'International Journal of Hydrogen Energy 56, 1371-1383, 2024'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:w1G5vK4DiEkC', 'num_citations': 4, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12759945443729477752', 'cites_id': ['12759945443729477752']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Design and Implementation of a Control Strategy for a Dynamic Organic Rankine Cycle‐Based Power System in the Context of Industrial Waste Heat Recovery', 'pub_year': '2023', 'citation': 'Energy Technology 11 (11), 2300425, 2023'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:ClN-LZ0IzgkC', 'num_citations': 4, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16758738523645461218', 'cites_id': ['16758738523645461218']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Two Stage Radial Compressor for a Kilowatt Scale Supercritical Carbon Dioxide Power Block: Design Considerations', 'pub_year': '2022', 'citation': 'Turbo Expo: Power for Land, Sea, and Air 86083, V009T28A006, 2022'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:Ui6Ig_dFDbcC', 'num_citations': 4, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13004636420202298895', 'cites_id': ['13004636420202298895']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Bearing selection for high-speed electrical machine', 'pub_year': '2021', 'citation': '2021 National Power Electronics Conference (NPEC), 01-06, 2021'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:Xnn2mF3JXD4C', 'num_citations': 4, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=18148416564810437671', 'cites_id': ['18148416564810437671']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Theoretical Estimation of Minimum and Maximum Allowable Rotational Speed of Supercritical CO2 Inward Flow Radial Turbine', 'pub_year': '2021', 'citation': 'Gas Turbine India Conference 85536, V001T12A007, 2021'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:N5XbD978G_MC', 'num_citations': 4, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17719076234141857496', 'cites_id': ['17719076234141857496']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Analysis of Aerostatic Thrust Bearing for S-CO2 Turbomachinery', 'pub_year': '2019', 'citation': 'Gas Turbine India Conference 83525, V001T05A015, 2019'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:cFcI8uaobsAC', 'num_citations': 4, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4437341959132920824', 'cites_id': ['4437341959132920824']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Feasibility of a Direct Coupled Turbine-Compressor Power Block for S-CO2 Brayton Cycles', 'pub_year': '2016', 'citation': 'Turbo Expo: Power for Land, Sea, and Air 49873, V009T36A009, 2016'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:Tiz5es2fbqcC', 'num_citations': 4, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16869388798776089519', 'cites_id': ['16869388798776089519']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Thermo-economic analysis of a mixture of RC-318 and pentane as a working fluid in a high temperature ORC', 'pub_year': '2015', 'citation': 'Proceedings of the 3rd International Seminar on ORC Power Systems, Brussels …, 2015'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:XiSMed-E-HIC', 'num_citations': 4, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16776643744968302133', 'cites_id': ['16776643744968302133']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Effect of temperature difference across ORC boiler on the thermal storage medium cost in a solar ORC', 'pub_year': '2015', 'citation': '3rd International Seminar on ORC Power Systems. Brussels, 2015'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:kNdYIx-mwKoC', 'num_citations': 4, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3805867174863086537', 'cites_id': ['3805867174863086537']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Solidification of A356 alloy in a linear electromagnetic stirrer', 'pub_year': '2008', 'citation': 'Solid State Phenomena 141, 563-568, 2008'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:B3FOqHPlNUQC', 'num_citations': 4, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9760878205697559191', 'cites_id': ['9760878205697559191']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Sliding Pressure Inventory Control of a Supercritical CO2 Cycle for Concentrated Solar Power—Analysis and Implications', 'pub_year': '2024', 'citation': 'Journal of Solar Energy Engineering 146 (1), 2024'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:qyimiW2FXDQC', 'num_citations': 3, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5289312614471119215', 'cites_id': ['5289312614471119215']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Specific Speed Considerations for Inward Flow Radial Supercritical CO2 Turbines', 'pub_year': '2022', 'citation': 'Turbo Expo: Power for Land, Sea, and Air 86083, V009T28A011, 2022'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:mZB2-lCpWbQC', 'num_citations': 3, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5790604404875959802', 'cites_id': ['5790604404875959802']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Profile loss investigations with a S-CO2 axial turbine aerofoil', 'pub_year': '2020', 'citation': 'Turbo Expo: Power for Land, Sea, and Air 84232, V011T31A015, 2020'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:rGOK5rmJZT0C', 'num_citations': 3, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8148367272680768123', 'cites_id': ['8148367272680768123']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Experimental investigations on a high-speed rotor for a switched reluctance machine', 'pub_year': '2018', 'citation': '2018 8th IEEE India International Conference on Power Electronics (IICPE), 1-6, 2018'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:D03iK_w7-QYC', 'num_citations': 3, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13462285845120667842', 'cites_id': ['13462285845120667842']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Optimization of Operating Parameters of a Recompression sCO2 Cycle for Maximum Efficiency', 'pub_year': '2017', 'citation': 'Turbo Expo: Power for Land, Sea, and Air 50961, V009T38A022, 2017'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:7PzlFSSx8tAC', 'num_citations': 3, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5434249855881108864', 'cites_id': ['5434249855881108864']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Supercritical carbon dioxide-based power cycles', 'pub_year': '2017', 'citation': 'Elsevier, 2017'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:eQOLeE2rZwMC', 'num_citations': 3, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2458337720176042203', 'cites_id': ['2458337720176042203']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Elevation of Heat Rejection Temperature in Transcritical Condensing Cycles Using CO2+Propane Mixtures', 'pub_year': '2014', 'citation': 'Turbo Expo: Power for Land, Sea, and Air 45660, V03BT36A015, 2014'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:5nxA0vEk-isC', 'num_citations': 3, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3582661321644693656', 'cites_id': ['3582661321644693656']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Moment analysis of a scroll expander used in an organic Rankine cycle', 'pub_year': '2014', 'citation': 'Turbo Expo: Power for Land, Sea, and Air 45660, V03BT26A014, 2014'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:u-x6o8ySG0sC', 'num_citations': 3, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=106259456662139349', 'cites_id': ['106259456662139349']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Solar thermal power system augmented with LHP', 'pub_year': '2014', 'citation': 'Energy Procedia 49, 295-304, 2014'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:isC4tDSrTZIC', 'num_citations': 3, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8234945878298661207', 'cites_id': ['8234945878298661207']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Emerging Data Center Thermal Management and Energy Efficiency Technologies', 'pub_year': '2012', 'citation': 'Energy Efficient Thermal Management of Data Centers, 569-611, 2012'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:hMod-77fHWUC', 'num_citations': 3, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9022970211955593435', 'cites_id': ['9022970211955593435']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Experimental Investigations on 10,000-RPM Slitted-Rotor Switched Reluctance Machine', 'pub_year': '2022', 'citation': '2022 IEEE Energy Conversion Congress and Exposition (ECCE), 1-7, 2022'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:_V0JUKP8578C', 'num_citations': 2, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9732579672177628271', 'cites_id': ['9732579672177628271']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Vaneless Diffuser Performance in a Super-Critical Carbon Dioxide Centrifugal Compressor With Real Gas Effects', 'pub_year': '2021', 'citation': 'Gas Turbine India Conference 85536, V001T04A007, 2021'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:SC9kKMAi-DoC', 'num_citations': 2, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16369962956701733397', 'cites_id': ['16369962956701733397']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Preliminary Aerodynamic Design of a S-CO2 Axial Turbine', 'pub_year': '2021', 'citation': 'Gas Turbine India Conference 85536, V001T12A009, 2021'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:m8MyhXdlT-4C', 'num_citations': 2, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7394684312071954421', 'cites_id': ['7394684312071954421']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Thermal resistance-capacitance network model for a PCM coupled heat pipe', 'pub_year': '2021', 'citation': '2021 20th IEEE Intersociety Conference on Thermal and Thermomechanical …, 2021'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:lbI08cpqPnQC', 'num_citations': 2, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13190351465262582517', 'cites_id': ['13190351465262582517']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Modelling of Gas Cooler for S-CO2 Brayton Power Cycle', 'pub_year': '2019', 'citation': 'Gas Turbine India Conference 83532, V002T08A010, 2019'}, 'filled': False, 'author_pub_id': 'wGXkEP0AAAAJ:TKVID9p7UpsC', 'num_citations': 2, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6139542183032841962', 'cites_id': ['6139542183032841962']}
# ...
# Retrieving publications for Dr. Sharath Sathish (ID: dcyu5ucAAAAJ)
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Equation of state based analytical formulation for optimization of sCO2 Brayton cycle', 'pub_year': '2021', 'citation': 'The Journal of Supercritical Fluids 177, 105351, 2021'}, 'filled': False, 'author_pub_id': 'dcyu5ucAAAAJ:IjCSPb-OGe4C', 'num_citations': 14, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17154047698526211220', 'cites_id': ['17154047698526211220']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Analysis of a 10 MW recompression supercritical carbon dioxide cycle for tropical climatic conditions', 'pub_year': '2021', 'citation': 'Applied Thermal Engineering 186, 116499, 2021'}, 'filled': False, 'author_pub_id': 'dcyu5ucAAAAJ:u5HHmVD_uO8C', 'num_citations': 11, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3217622347219356704', 'cites_id': ['3217622347219356704']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Novel Approaches for sCO2 Axial Turbine Design', 'pub_year': '2019', 'citation': 'Turbo Expo: Power for Land, Sea, and Air 58721, V009T38A011, 2019'}, 'filled': False, 'author_pub_id': 'dcyu5ucAAAAJ:2osOgNQ5qMEC', 'num_citations': 11, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12758375393937637965', 'cites_id': ['12758375393937637965']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Design of 20 kW Turbomachinery for Closed Loop Supercritical Carbon Dioxide Brayton Test Loop Facility', 'pub_year': '2019', 'citation': 'Turbo Expo: Power for Land, Sea, and Air 58721, V009T38A016, 2019'}, 'filled': False, 'author_pub_id': 'dcyu5ucAAAAJ:d1gkVwhDpl0C', 'num_citations': 11, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8893177805644202701', 'cites_id': ['8893177805644202701']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Simple Recuperated s-CO2 Cycle Revisited: Optimization of Operating Parameters for Maximum Cycle Efficiency', 'pub_year': '2019', 'citation': 'Turbo Expo: Power for Land, Sea, and Air 58721, V009T38A002, 2019'}, 'filled': False, 'author_pub_id': 'dcyu5ucAAAAJ:qjMakFHDy7sC', 'num_citations': 7, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16076966250126982478', 'cites_id': ['16076966250126982478']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Optimization of Operating Parameters of a Recompression sCO2 Cycle for Maximum Efficiency', 'pub_year': '2017', 'citation': 'Turbo Expo: Power for Land, Sea, and Air 50961, V009T38A022, 2017'}, 'filled': False, 'author_pub_id': 'dcyu5ucAAAAJ:u-x6o8ySG0sC', 'num_citations': 3, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5434249855881108864', 'cites_id': ['5434249855881108864']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Power plants with an integrally geared steam compressor', 'pub_year': '2016', 'citation': 'US Patent App. 15/029,317, 2016'}, 'filled': False, 'author_pub_id': 'dcyu5ucAAAAJ:UeHWp8X0CEIC', 'num_citations': 2, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17952565999759482374', 'cites_id': ['17952565999759482374']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Brayton Cycle Supercritical CO2 Power Block for Industrial Waste Heat Recovery', 'pub_year': '2019', 'citation': 'Gas Turbine India Conference 83532, V002T08A001, 2019'}, 'filled': False, 'author_pub_id': 'dcyu5ucAAAAJ:9yKSN-GCB0IC', 'num_citations': 1, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9988973399805097595', 'cites_id': ['9988973399805097595']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Wind Tunnel Testing and Modeling Implications of an Advanced Turbine Cascade', 'pub_year': '2024', 'citation': 'arXiv preprint arXiv:2407.11210, 2024'}, 'filled': False, 'author_pub_id': 'dcyu5ucAAAAJ:Tyk-4Ss8FVUC', 'num_citations': 0}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Centrifugal Compressor Design and Surge Simulation for Active Inference Based Control', 'pub_year': '2024', 'citation': 'Turbo Expo: Power for Land, Sea, and Air 88018, V009T19A011, 2024'}, 'filled': False, 'author_pub_id': 'dcyu5ucAAAAJ:Y0pCki6q_DkC', 'num_citations': 0}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Test rig design for experimental characterisation of condensation in sCO2 compressors', 'citation': ''}, 'filled': False, 'author_pub_id': 'dcyu5ucAAAAJ:zYLM7Y9cAGgC', 'num_citations': 0}
# Retrieving publications for Kundan Kumar (ID: YokW28IAAAAJ)
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Analysis of a hybrid transcritical CO2 vapor compression and vapor ejector refrigeration system', 'pub_year': '2020', 'citation': 'Applied Thermal Engineering 181, 115945, 2020'}, 'filled': False, 'author_pub_id': 'YokW28IAAAAJ:ULOm3_A8WrAC', 'num_citations': 28, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=14452470301901856610', 'cites_id': ['14452470301901856610']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Analysis of Propane + CO2 mixture as a working fluid in a vapor compression refrigeration system', 'pub_year': '2019', 'citation': '8th Conference on Ammonia and CO2 Refrigeration Technology Proceedings, 2019'}, 'filled': False, 'author_pub_id': 'YokW28IAAAAJ:Zph67rFs4hoC', 'num_citations': 8, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5602259911289506818', 'cites_id': ['5602259911289506818']}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Performance Analysis of CO2/Natural Refrigerants for Cascade Refrigeration System', 'pub_year': '2021', 'citation': 'Sixth International Conference on Polygeneration -ICP 2021, 505-514, 2021'}, 'filled': False, 'author_pub_id': 'YokW28IAAAAJ:YOwf2qJgpHMC', 'num_citations': 0}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Experimental analysis of transcritical CO2 booster refrigeration system with heat recovery and ejector expansion', 'pub_year': '2019', 'citation': 'Proceedings of the 25th IIR International Congress of Refrigeration, 2019'}, 'filled': False, 'author_pub_id': 'YokW28IAAAAJ:kNdYIx-mwKoC', 'num_citations': 0}
# Adding {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Analysis of a Hybrid CO2 Vapor Compression and Vapor Ejector Refrigeration System', 'pub_year': '2019', 'citation': '5th International Conference on Polygeneration, 2019'}, 'filled': False, 'author_pub_id': 'YokW28IAAAAJ:KlAtU1dfN6UC', 'num_citations': 0}
# Retrieving publications for Sanjoy Paul (ID: OfRkFNcAAAAJ)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32012\2166547463.py in <module>
#      26
#      27 # Example usage
# ---> 28 publication_titles = retrieve_publication_titles_for_lab_members()
#
# ~\AppData\Local\Temp\ipykernel_32012\2166547463.py in retrieve_publication_titles_for_lab_members(lab_members_filename)
#      12         scholar_id = member.get('scholar_id')
#      13         print(f"Retrieving publications for {member['name']} (ID: {scholar_id})")
# ---> 14         all_publications = scholarly.fill(scholarly.search_author_id(scholar_id))['publications']
#      15
#      16         for title in all_publications:
#
# ~\anaconda3\lib\site-packages\scholarly\_scholarly.py in fill(self, object, sections, sortby, publication_limit)
#     231         if object['container_type'] == "Author":
#     232             author_parser = AuthorParser(self.__nav)
# --> 233             object = author_parser.fill(object, sections, sortby, publication_limit)
#     234             if object is False:
#     235                 raise ValueError("Incorrect input")
#
# ~\anaconda3\lib\site-packages\scholarly\author_parser.py in fill(self, author, sections, sortby, publication_limit)
#     439             url_citations += sortby_str
#     440             url = '{0}&pagesize={1}'.format(url_citations, _PAGESIZE)
# --> 441             soup = self.nav._get_soup(url)
#     442
#     443             # Update scholar_id
#
# ~\anaconda3\lib\site-packages\scholarly\_navigator.py in _get_soup(self, url)
#     237     def _get_soup(self, url: str) -> BeautifulSoup:
#     238         """Return the BeautifulSoup for a page on scholar.google.com"""
# --> 239         html = self._get_page('https://scholar.google.com{0}'.format(url))
#     240         html = html.replace(u'\xa0', u' ')
#     241         res = BeautifulSoup(html, 'html.parser')
#
# ~\anaconda3\lib\site-packages\scholarly\_navigator.py in _get_page(self, pagerequest, premium)
#     112                 w = random.uniform(1,2)
#     113                 time.sleep(w)
# --> 114                 resp = session.get(pagerequest, timeout=timeout)
#     115                 if premium is False:  # premium methods may contain sensitive information
#     116                     self.logger.debug("Session proxy config is {}".format(pm._proxies))
#
# ~\anaconda3\lib\site-packages\httpx\_client.py in get(self, url, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1051         **Parameters**: See `httpx.request`.
#    1052         """
# -> 1053         return self.request(
#    1054             "GET",
#    1055             url,
#
# ~\anaconda3\lib\site-packages\httpx\_client.py in request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     823             extensions=extensions,
#     824         )
# --> 825         return self.send(request, auth=auth, follow_redirects=follow_redirects)
#     826
#     827     @contextmanager
#
# ~\anaconda3\lib\site-packages\httpx\_client.py in send(self, request, stream, auth, follow_redirects)
#     926         except BaseException as exc:
#     927             response.close()
# --> 928             raise exc
#     929
#     930     def _send_handling_auth(
#
# ~\anaconda3\lib\site-packages\httpx\_client.py in send(self, request, stream, auth, follow_redirects)
#     920         try:
#     921             if not stream:
# --> 922                 response.read()
#     923
#     924             return response
#
# ~\anaconda3\lib\site-packages\httpx\_models.py in read(self)
#     879         """
#     880         if not hasattr(self, "_content"):
# --> 881             self._content = b"".join(self.iter_bytes())
#     882         return self._content
#     883
#
# ~\anaconda3\lib\site-packages\httpx\_models.py in iter_bytes(self, chunk_size)
#     895             chunker = ByteChunker(chunk_size=chunk_size)
#     896             with request_context(request=self._request):
# --> 897                 for raw_bytes in self.iter_raw():
#     898                     decoded = decoder.decode(raw_bytes)
#     899                     for chunk in chunker.decode(decoded):
#
# ~\anaconda3\lib\site-packages\httpx\_models.py in iter_raw(self, chunk_size)
#     949
#     950         with request_context(request=self._request):
# --> 951             for raw_stream_bytes in self.stream:
#     952                 self._num_bytes_downloaded += len(raw_stream_bytes)
#     953                 for chunk in chunker.decode(raw_stream_bytes):
#
# ~\anaconda3\lib\site-packages\httpx\_client.py in __iter__(self)
#     151
#     152     def __iter__(self) -> typing.Iterator[bytes]:
# --> 153         for chunk in self._stream:
#     154             yield chunk
#     155
#
# ~\anaconda3\lib\site-packages\httpx\_transports\default.py in __iter__(self)
#     125     def __iter__(self) -> typing.Iterator[bytes]:
#     126         with map_httpcore_exceptions():
# --> 127             for part in self._httpcore_stream:
#     128                 yield part
#     129
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\connection_pool.py in __iter__(self)
#     405         except BaseException as exc:
#     406             self.close()
# --> 407             raise exc from None
#     408
#     409     def close(self) -> None:
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\connection_pool.py in __iter__(self)
#     401     def __iter__(self) -> typing.Iterator[bytes]:
#     402         try:
# --> 403             for part in self._stream:
#     404                 yield part
#     405         except BaseException as exc:
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\http11.py in __iter__(self)
#     340             with ShieldCancellation():
#     341                 self.close()
# --> 342             raise exc
#     343
#     344     def close(self) -> None:
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\http11.py in __iter__(self)
#     332         try:
#     333             with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334                 for chunk in self._connection._receive_response_body(**kwargs):
#     335                     yield chunk
#     336         except BaseException as exc:
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\http11.py in _receive_response_body(self, request)
#     201
#     202         while True:
# --> 203             event = self._receive_event(timeout=timeout)
#     204             if isinstance(event, h11.Data):
#     205                 yield bytes(event.data)
#
# ~\anaconda3\lib\site-packages\httpcore\_sync\http11.py in _receive_event(self, timeout)
#     215
#     216             if event is h11.NEED_DATA:
# --> 217                 data = self._network_stream.read(
#     218                     self.READ_NUM_BYTES, timeout=timeout
#     219                 )
#
# ~\anaconda3\lib\site-packages\httpcore\_backends\sync.py in read(self, max_bytes, timeout)
#     126         with map_exceptions(exc_map):
#     127             self._sock.settimeout(timeout)
# --> 128             return self._sock.recv(max_bytes)
#     129
#     130     def write(self, buffer: bytes, timeout: float | None = None) -> None:
#
# ~\anaconda3\lib\ssl.py in recv(self, buflen, flags)
#    1225                     "non-zero flags not allowed in calls to recv() on %s" %
#    1226                     self.__class__)
# -> 1227             return self.read(buflen)
#    1228         else:
#    1229             return super().recv(buflen, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1100                 return self._sslobj.read(len, buffer)
#    1101             else:
# -> 1102                 return self._sslobj.read(len)
#    1103         except SSLError as x:
#    1104             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
publication_titles
